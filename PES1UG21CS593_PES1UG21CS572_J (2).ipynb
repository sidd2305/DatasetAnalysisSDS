# %%
#ALL THE INFERENCES AND OBSERVATIONS HAVE BEEN COMMENTED
#kindly consider it
import pandas as pd
import chardet
df=pd.read_csv(r"C:\Users\Shreya\Downloads\SDS_Hackathon_Dataset_30_11_22.csv")
df
# Out:
#      Unnamed: 0  Active  Rest  Smoke  Gender  Exercise   Hgt    Wgt
# 0             0    97.0  78.0    0.0     1.0       1.0  63.0  119.0
# 1             1    82.0  68.0    1.0     0.0       3.0  70.0  225.0
# 2             2    88.0  62.0    0.0     0.0       3.0  72.0  175.0
# 3             3   106.0  74.0    0.0     0.0       3.0  72.0  170.0
# 4             4    78.0  63.0    0.0     1.0       3.0  67.0  125.0
# ..          ...     ...   ...    ...     ...       ...   ...    ...
# 227         227   105.0  85.0    0.0     1.0       2.0  64.0  150.0
# 228         228    82.0  74.0    0.0     1.0       3.0  66.0  124.0
# 229         229   102.0  81.0    0.0     0.0       2.0  69.0  172.0
# 230         230    87.0  67.0    0.0     0.0       2.0  68.0  170.0
# 231         231    81.0  62.0    0.0     0.0       3.0  68.0  151.0
#
# [232 rows x 8 columns]

# %%
#set of attributes
df.head()
# Out:
#    Unnamed: 0  Active  Rest  Smoke  Gender  Exercise   Hgt    Wgt
# 0           0    97.0  78.0    0.0     1.0       1.0  63.0  119.0
# 1           1    82.0  68.0    1.0     0.0       3.0  70.0  225.0
# 2           2    88.0  62.0    0.0     0.0       3.0  72.0  175.0
# 3           3   106.0  74.0    0.0     0.0       3.0  72.0  170.0
# 4           4    78.0  63.0    0.0     1.0       3.0  67.0  125.0

# %%
#high level charecterstics
df.describe()
# Out:
#        Unnamed: 0      Active        Rest       Smoke      Gender    Exercise  \
# count  232.000000  230.000000  229.000000  228.000000  226.000000  231.000000
# mean   115.500000   91.313043   68.358079    0.114035    0.469027    2.259740
# std     67.116814   18.880625   10.007155    0.318553    0.500147    0.735484
# min      0.000000   51.000000   43.000000    0.000000    0.000000    1.000000
# 25%     57.750000   79.000000   62.000000    0.000000    0.000000    2.000000
# 50%    115.500000   88.500000   68.000000    0.000000    0.000000    2.000000
# 75%    173.250000  102.000000   74.000000    0.000000    1.000000    3.000000
# max    231.000000  154.000000  106.000000    1.000000    1.000000    3.000000
#
#               Hgt         Wgt
# count  223.000000  217.000000
# mean    68.327354  158.138249
# std      3.736298   31.381306
# min     60.000000  102.000000
# 25%     65.000000  135.000000
# 50%     69.000000  151.000000
# 75%     71.000000  175.000000
# ...

# %%
df.count()
# Out:
# Unnamed: 0    232
# Active        230
# Rest          229
# Smoke         228
# Gender        226
# Exercise      231
# Hgt           223
# Wgt           217
# dtype: int64

# %%
df.shape
#number of students surveyed is 232
# Out:
# (232, 8)

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Active        float64
# Rest          float64
# Smoke         float64
# Gender        float64
# Exercise      float64
# Hgt           float64
# Wgt           float64
# dtype: object

# %%
df._get_numeric_data()
# Out:
#      Unnamed: 0  Active  Rest  Smoke  Gender  Exercise   Hgt    Wgt
# 0             0    97.0  78.0    0.0     1.0       1.0  63.0  119.0
# 1             1    82.0  68.0    1.0     0.0       3.0  70.0  225.0
# 2             2    88.0  62.0    0.0     0.0       3.0  72.0  175.0
# 3             3   106.0  74.0    0.0     0.0       3.0  72.0  170.0
# 4             4    78.0  63.0    0.0     1.0       3.0  67.0  125.0
# ..          ...     ...   ...    ...     ...       ...   ...    ...
# 227         227   105.0  85.0    0.0     1.0       2.0  64.0  150.0
# 228         228    82.0  74.0    0.0     1.0       3.0  66.0  124.0
# 229         229   102.0  81.0    0.0     0.0       2.0  69.0  172.0
# 230         230    87.0  67.0    0.0     0.0       2.0  68.0  170.0
# 231         231    81.0  62.0    0.0     0.0       3.0  68.0  151.0
#
# [232 rows x 8 columns]

# %%
#Active  is numeric
#rest is numeric
#height and weight is numeric
#smoke and gender are categorical
#Exercise is numerical but discrete

#height,weight,continous,active,rest are continous
#smoke and gender is nominal
#excercise is discrete

# %%
#mean of each column
df2=df.mean(axis=0)
print(df2)
# Out:
# Unnamed: 0    115.500000
# Active         91.313043
# Rest           68.358079
# Smoke           0.114035
# Gender          0.469027
# Exercise        2.259740
# Hgt            68.327354
# Wgt           158.138249
# dtype: float64

# %%
#mode of each column
df2=df.mode()
print(df2)
# Out:
#      Unnamed: 0  Active  Rest  Smoke  Gender  Exercise   Hgt    Wgt
# 0             0    80.0  63.0    0.0     0.0       3.0  70.0  150.0
# 1             1     NaN   NaN    NaN     NaN       NaN   NaN    NaN
# 2             2     NaN   NaN    NaN     NaN       NaN   NaN    NaN
# 3             3     NaN   NaN    NaN     NaN       NaN   NaN    NaN
# 4             4     NaN   NaN    NaN     NaN       NaN   NaN    NaN
# ..          ...     ...   ...    ...     ...       ...   ...    ...
# 227         227     NaN   NaN    NaN     NaN       NaN   NaN    NaN
# 228         228     NaN   NaN    NaN     NaN       NaN   NaN    NaN
# 229         229     NaN   NaN    NaN     NaN       NaN   NaN    NaN
# 230         230     NaN   NaN    NaN     NaN       NaN   NaN    NaN
# 231         231     NaN   NaN    NaN     NaN       NaN   NaN    NaN
#
# [232 rows x 8 columns]

# %%
#median of each column
df2=df.median(axis=0)
print(df2)
# Out:
# Unnamed: 0    115.5
# Active         88.5
# Rest           68.0
# Smoke           0.0
# Gender          0.0
# Exercise        2.0
# Hgt            69.0
# Wgt           151.0
# dtype: float64

# %%
#for active and rest mean is the most effective measure of central tendency
#for height and weight mean is the most effective measure of central tendency
#for smoke,gender and exercise mode is the most effective measure

# %%
#standard deviation of each attribute
df.std(axis=None)
# Out:
# Unnamed: 0    67.116814
# Active        18.880625
# Rest          10.007155
# Smoke          0.318553
# Gender         0.500147
# Exercise       0.735484
# Hgt            3.736298
# Wgt           31.381306
# dtype: float64

# %%
#range of each column
df.max()-df.min()
# Out:
# Unnamed: 0    231.0
# Active        103.0
# Rest           63.0
# Smoke           1.0
# Gender          1.0
# Exercise        2.0
# Hgt            18.0
# Wgt           158.0
# dtype: float64

# %%
 #number of missing values in each column 
missingv=df.isnull()
count_missing_values=missingv.sum()
print(count_missing_values)
# Out:
# Unnamed: 0     0
# Active         2
# Rest           3
# Smoke          4
# Gender         6
# Exercise       1
# Hgt            9
# Wgt           15
# dtype: int64

# %%
#transforming each column to ensure no column has missing values
print(df.fillna(method="bfill"))
# Out:
#      Unnamed: 0  Active  Rest  Smoke  Gender  Exercise   Hgt    Wgt
# 0             0    97.0  78.0    0.0     1.0       1.0  63.0  119.0
# 1             1    82.0  68.0    1.0     0.0       3.0  70.0  225.0
# 2             2    88.0  62.0    0.0     0.0       3.0  72.0  175.0
# 3             3   106.0  74.0    0.0     0.0       3.0  72.0  170.0
# 4             4    78.0  63.0    0.0     1.0       3.0  67.0  125.0
# ..          ...     ...   ...    ...     ...       ...   ...    ...
# 227         227   105.0  85.0    0.0     1.0       2.0  64.0  150.0
# 228         228    82.0  74.0    0.0     1.0       3.0  66.0  124.0
# 229         229   102.0  81.0    0.0     0.0       2.0  69.0  172.0
# 230         230    87.0  67.0    0.0     0.0       2.0  68.0  170.0
# 231         231    81.0  62.0    0.0     0.0       3.0  68.0  151.0
#
# [232 rows x 8 columns]

# %%
df.fillna(method="bfill").isnull()
#to check if all the null values have been replaced by bfill
# Out:
#      Unnamed: 0  Active   Rest  Smoke  Gender  Exercise    Hgt    Wgt
# 0         False   False  False  False   False     False  False  False
# 1         False   False  False  False   False     False  False  False
# 2         False   False  False  False   False     False  False  False
# 3         False   False  False  False   False     False  False  False
# 4         False   False  False  False   False     False  False  False
# ..          ...     ...    ...    ...     ...       ...    ...    ...
# 227       False   False  False  False   False     False  False  False
# 228       False   False  False  False   False     False  False  False
# 229       False   False  False  False   False     False  False  False
# 230       False   False  False  False   False     False  False  False
# 231       False   False  False  False   False     False  False  False
#
# [232 rows x 8 columns]

# %%
#number of classes of active
df.Active.value_counts()
# Out:
# 80.0     15
# 88.0      8
# 102.0     8
# 110.0     8
# 82.0      7
#          ..
# 73.0      1
# 61.0      1
# 140.0     1
# 134.0     1
# 56.0      1
# Name: Active, Length: 73, dtype: int64

# %%
#number of classes of rest
df.Rest.value_counts()
# Out:
# 63.0     15
# 68.0     13
# 72.0     13
# 64.0     11
# 74.0     11
# 58.0     10
# 78.0      9
# 67.0      9
# 70.0      9
# 80.0      8
# 60.0      8
# 65.0      8
# 75.0      7
# 61.0      7
# 62.0      7
# 73.0      6
# 66.0      6
# 71.0      6
# 69.0      6
# 54.0      5
# 55.0      5
# 77.0      4
# 53.0      4
# 81.0      3
# 59.0      3
# 82.0      3
# 57.0      3
# 85.0      3
# 76.0      2
# 48.0      2
# 84.0      2
# 83.0      2
# 92.0      2
# 79.0      2
# 56.0      2
# 52.0      2
# 50.0      1
# 47.0      1
# 51.0      1
# 43.0      1
# 97.0      1
# 106.0     1
# 95.0      1
# 88.0      1
# 90.0      1
# 94.0      1
# 98.0      1
# Name: Rest, dtype: int64

# %%
#number of classes of smoke
df.Smoke.value_counts()
# Out:
# 0.0    202
# 1.0     26
# Name: Smoke, dtype: int64

# %%
#number of classes of Gender
df.Gender.value_counts()
# Out:
# 0.0    120
# 1.0    106
# Name: Gender, dtype: int64

# %%
#number of classes of exercise
df.Exercise.value_counts()
# Out:
# 3.0    100
# 2.0     91
# 1.0     40
# Name: Exercise, dtype: int64

# %%
#number of classes of height
df.Hgt.value_counts()
# Out:
# 70.0    31
# 67.0    25
# 71.0    21
# 72.0    20
# 68.0    17
# 64.0    17
# 65.0    15
# 69.0    14
# 74.0    12
# 66.0    12
# 63.0    10
# 61.0     7
# 62.0     7
# 73.0     6
# 75.0     4
# 76.0     2
# 60.0     1
# 77.0     1
# 78.0     1
# Name: Hgt, dtype: int64

# %%
#number of classes of weight
df.Wgt.value_counts()
# Out:
# 150.0    17
# 135.0    15
# 145.0    15
# 175.0    13
# 165.0    10
#          ..
# 123.0     1
# 238.0     1
# 208.0     1
# 157.0     1
# 105.0     1
# Name: Wgt, Length: 68, dtype: int64

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import math
import statistics
import seaborn as sns

# %%
#BAR GRAPH OF GENDER AND FREQUENCY
df['Gender'].value_counts().plot(kind='bar')
plt.xlabel('Male                                   Female')
plt.ylabel('Number of people')
#Number of men are more than women
#Not a normal distribution
df.
# Out:
# Text(0, 0.5, 'Number of people')

# %%
#BAR GRAPH OF SMOKING AND NON-SMOKING PEOPLE AND THEIR FREQUENCY
df['Smoke'].value_counts().plot(kind='bar')
plt.xlabel('Non-Smokers                           Smokers')
plt.ylabel('Number of people')

#not a normal distribution, number of NON-smokers is greater than smokers
# Out:
# Text(0, 0.5, 'Number of people')

# %%
#histogram for Active Pulse
#Active pulse:Moderately skewed
#unimodal
x=df.Active
plt.hist(x)

plt.xlabel("Active pulse")
plt.ylabel("Number of people")
plt.show()

# %%
#histogram for Rest pulse
#Rest:Moderately skewed
#unimodal
x=df.Rest
plt.hist(x)

plt.xlabel("Rest pulse")
plt.ylabel("Number of people")
plt.show()

# %%
#histogram for Exercise
#Exercise:Fairly symmetric
#numerical but discrete

x=df.Exercise
plt.hist(x)

plt.xlabel("Number of hours exercised")
plt.ylabel("Number of people")
plt.show()

# %%
#histogram for Height
#unimodal
#Height:Fairly symmertric

x=df.Rest
plt.hist(x)

plt.xlabel("Height in inches")
plt.ylabel("Number of people")
plt.show()

# %%
#histogram for Weight
#Weight:Moderately skewed

x=df.Rest
plt.hist(x)

plt.xlabel("Weight in pounds")
plt.ylabel("Number of people")
plt.show()

# %%
df.skew(axis=0)
#skewness of each distribution
#Active:Moderately skewed
#Rest:Moderately skewed
#Smoke:Highly skewed
#Gender:Fairly symmetric
#Exercise:Fairly symmetric
#Height:Fairly symmertric
#Weight:Moderately skewed


#If the skewness is between -0.5 and 0.5, the data are fairly symmetrical
#If the skewness is between -1 and – 0.5 or between 0.5 and 1, the data are moderately skewed
#If the skewness is less than -1 or greater than 1, the data are highly skewed
# Out:
# Unnamed: 0    0.000000
# Active        0.671057
# Rest          0.517814
# Smoke         2.444681
# Gender        0.124963
# Exercise     -0.451919
# Hgt          -0.066607
# Wgt           0.712932
# dtype: float64

# %%
#describing distribution around mean -number of peaks for modality
df.kurtosis(axis=0)
# Out:
# Unnamed: 0   -1.200000
# Active        0.414502
# Rest          0.796429
# Smoke         4.011579
# Gender       -2.002182
# Exercise     -1.038880
# Hgt          -0.618610
# Wgt           0.523404
# dtype: float64

# %%
#boxplot for active pulse
sns.boxplot(df.Active)
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Active'>

# %%
#boxplot for Rest pulse
sns.boxplot(df.Rest)
# Out:
# C:\Users\Shreya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Rest'>

# %%
#interquartile range of active and rest pulse
import numpy as np

iqr=df['Active'].quantile(0.75)-df['Active'].quantile(0.25)
iqr1=df['Rest'].quantile(0.75)-df['Rest'].quantile(0.25)
print("Interquartile range of active pulse",iqr)

print("Interquartile range of Rest pulse",iqr1)
# Out:
# Interquartile range of active pulse 23.0
# Interquartile range of Rest pulse 12.0

# %%
#interquartile range of active pulse is greater than rest pulse

# %%
#VISUALIZING GROUPED DATA
#active pulse rate and gender
male=df.loc[df["Gender"]==0.0]["Active"]
female=df.loc[df["Gender"]==1.0]["Active"]
plt.hist([male,female])
plt.legend(["male","female"])
plt.xlabel("Active pulse rate")
plt.ylabel("Number of people")
plt.show()

#rest pulse rate and gender
male=df.loc[df["Gender"]==0.0]["Rest"]
female=df.loc[df["Gender"]==1.0]["Rest"]
plt.hist([male,female])
plt.legend(["male","female"])
plt.xlabel("Rest pulse rate")
plt.ylabel("Number of people")
plt.show()

#females have have higher active and rest pulse rate

# %%
#active pulse rate and excercise
a=df.loc[df["Exercise"]==1.0]["Active"]
b=df.loc[df["Exercise"]==2.0]["Active"]
c=df.loc[df["Exercise"]==3.0]["Active"]
plt.hist([a,b,c])
plt.legend(["1 hour","2 hour","3 hour"])
plt.xlabel("Active pulse rate")
plt.ylabel("Number of people")
plt.show()

#Rest pulse rate and excercise
a=df.loc[df["Exercise"]==1.0]["Rest"]
b=df.loc[df["Exercise"]==2.0]["Rest"]
c=df.loc[df["Exercise"]==3.0]["Rest"]
plt.hist([a,b,c])
plt.legend(["1 hour","2 hour","3 hour"])
plt.xlabel("Rest pulse rate")
plt.ylabel("Number of people")
plt.show()


#less exercise higher heart rate

# %%
#active pulse rate and smoking
male=df.loc[df["Smoke"]==0.0]["Active"]
female=df.loc[df["Smoke"]==1.0]["Active"]
plt.hist([male,female])
plt.legend(["Non Smoker","Smoker"])
plt.xlabel("Active pulse rate")
plt.ylabel("Number of people")
plt.show()

#rest pulse rate and smoking
male=df.loc[df["Smoke"]==0.0]["Rest"]
female=df.loc[df["Smoke"]==1.0]["Rest"]
plt.hist([male,female])
plt.legend(["Non Smoker","Smoker"])
plt.xlabel("Rest pulse rate")
plt.ylabel("Number of people")
plt.show()

#non-smokers have a higher active and rest pulse rate compared to smokers

# %%
#we have explored all the possible combination of scatter plot matrix for numeric-numeric, 
#categoric-categoric and numeric-categoric
sns.set_theme(style="ticks")
sns.pairplot(df)

# %%
#visually we feel height and weight have the highest linear relationship

# %%
#pearson's coefficient 
df.corr()
# Out:
#             Unnamed: 0    Active      Rest     Smoke    Gender  Exercise  \
# Unnamed: 0    1.000000 -0.049312  0.043458 -0.041439 -0.028057 -0.029691
# Active       -0.049312  1.000000  0.604856  0.112284  0.186648 -0.362495
# Rest          0.043458  0.604856  1.000000  0.158974  0.169627 -0.542523
# Smoke        -0.041439  0.112284  0.158974  1.000000 -0.092514 -0.216923
# Gender       -0.028057  0.186648  0.169627 -0.092514  1.000000 -0.137468
# Exercise     -0.029691 -0.362495 -0.542523 -0.216923 -0.137468  1.000000
# Hgt          -0.013373 -0.168624 -0.234041  0.083962 -0.753590  0.177683
# Wgt           0.038033 -0.093927 -0.221376  0.126416 -0.699562  0.186452
#
#                  Hgt       Wgt
# Unnamed: 0 -0.013373  0.038033
# Active     -0.168624 -0.093927
# Rest       -0.234041 -0.221376
# Smoke       0.083962  0.126416
# Gender     -0.753590 -0.699562
# Exercise    0.177683  0.186452
# Hgt         1.000000  0.749479
# Wgt         0.749479  1.000000

# %%
#height and weight have highest value of the pearson's coefficient which is 0.749479 , hence validated

# %%
#Linear regression model for active and rest-evaluating goodness of fit
from sklearn.metrics import r2_score
x=np.array(df["Rest"].tolist())
y=np.array(df["Active"].tolist())
print("Rest",x)
print("Active",y)
plt.plot(x,y,"ro")
b1,b0=np.polyfit(x,y,deg=1)
print("y hat = ",b0,"+",b1,"x")
ypred=b0+b1*x
plt.plot(x,ypred)
plt.show()
print("R square is",r2_score(y,ypred))
residual=y-ypred
plt.plot(ypred,residual,"ro")
plt.hlines(0,0,12000)
#Linear regression is a fair representation model for the given data
# Out:
# Rest [ 78.  68.  62.  74.  63.  65.  43.  65.  63.  59.  57.  65.  85.  64.
#   70.  66.  72.  72.  75.  68.  72.  61.  74.  72.  72.  97.  64.  53.
#   78.  85.  80.  58.  77.  53.  75.  51.  74.  59.  47.  78.  78.  72.
#   70.  63.  60.  80.  67.  64.  65.  72.  65.  67.  69.  60.  62.  67.
#   71.  62.  54.  66.  77.  82.  78.  64.  58.  80.  92.  67.  64.  65.
#   63.  52.  74.  64.  66.  67.  58.  62.  77.  63.  69.  60.  60.  61.
#   70.  71.  63.  75.  71.  64.  56.  72.  65.  63.  79.  61.  68.  61.
#   67.  67.  54.  69.  58.  76.  68.  55.  83.  80.  56.  83.  74.  78.
#   61.  75.  72.  63.  78.  54.  80.  69.  50.  69.  80.  80.  63.  68.
#   64.  48.  82.  64.  79.  61.  73.  75.  59.  74.  66.  60.  76.  92.
#   71.  72.  68.  81.  68.  58.  63.  84.  74.  78.  68.  66.  70.  72.
#   84.  77.  78.  63.  60.  68.  80. 106.  73.  73.  55.  62.  63.  75.
#   54.  72.  63.  74.  58.  60.  70.  95.  88.  70.  82.  72.  58.  68.
# ...

# %%
#Fitted model equation and FINDING R squared value
from sklearn.metrics import r2_score
x=df.iloc[:,1]
y=df.iloc[:,2]

plt.plot(x,y,'ro')
b1,b0=np.polyfit(x,y,deg=1)
print("Fitted model linear equation","y_hat=",b0,"+",b1,"x")
ypredicted=b0+b1*x#predcited or fitted value
plt.plot(x,ypredicted)
plt.show()
rsq=r2_score(y,ypredicted)
print("R squared value",rsq)
# Out:
# Fitted model linear equation y_hat= 39.48084487771062 + 0.3169087384151429 x
# R squared value 0.3592747034585714
